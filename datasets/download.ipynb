# %%
import os 

from torchvision import datasets

# %%
dir_path = os.getcwd()

# %% [markdown]
# ## 1. CelebA dataset

# %%
! pip install gdown
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
celebA = datasets.CelebA(
    root=dir_path,
    split='all',
    download=True
)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=0B7EVK8r0v71pZjFTYXZWM3FlRnM
# From (redirected): https://drive.usercontent.google.com/download?id=0B7EVK8r0v71pZjFTYXZWM3FlRnM&confirm=t&uuid=3f8243e3-182b-48f3-8c23-cd10457ee275
# To: /workspaces/VAE-with-Pytorch/datasets/celeba/img_align_celeba.zip
# 100%|██████████| 1.44G/1.44G [00:31<00:00, 46.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=0B7EVK8r0v71pblRyaVFSWGxPY0U
# To: /workspaces/VAE-with-Pytorch/datasets/celeba/list_attr_celeba.txt
# 100%|██████████| 26.7M/26.7M [00:00<00:00, 33.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1_ee_0u7vcNLOfNLegJRHmolfH5ICW-XS
# To: /workspaces/VAE-with-Pytorch/datasets/celeba/identity_CelebA.txt
# 100%|██████████| 3.42M/3.42M [00:00<00:00, 156MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=0B7EVK8r0v71pbThiMVRxWXZ4dU0
# To: /workspaces/VAE-with-Pytorch/datasets/celeba/list_bbox_celeba.txt
# ...

# %%
celebA[100][0]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=178x218>
